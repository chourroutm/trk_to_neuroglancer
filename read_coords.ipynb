# %%
from dipy.io.streamline import load_tractogram
from dipy.io.stateful_tractogram import Space
from pathlib import Path

# Load the tractogram file (e.g., 'tractogram.trk')
tractogram = load_tractogram('./Stack_Synthetic_Data_Anti-Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen.trk',reference='same')

# Convert the streamlines to a numpy array in the RAS+ space
streamlines = tractogram.streamlines

# Extract the affine transformation matrix
affine = tractogram.affine

# Print the affine and the first streamline's coordinates as examples
print("Affine transformation matrix:")
print(affine)

# To get the coordinates of each streamline
streamline_coords = [s for s in streamlines]

# Print the number of streamlines
print("\nNumber of streamlines:")
print(len(streamline_coords))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 6
#       3 from pathlib import Path
#       5 # Load the tractogram file (e.g., 'tractogram.trk')
# ----> 6 tractogram = load_tractogram('./Stack_Synthetic_Data_Anti-Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen.trk',reference='same')
#       8 # Convert the streamlines to a numpy array in the RAS+ space
#       9 streamlines = tractogram.streamlines
#
# File d:\Matthieu\tracto\.venv\Lib\site-packages\dipy\io\streamline.py:143, in load_tractogram(filename, reference, to_space, to_origin, bbox_valid_check, trk_header_check)
#     140         return False
#     142 if trk_header_check and extension == '.trk':
# --> 143     if not is_header_compatible(filename, reference):
#     144         logging.error('Trk file header does not match the provided '
#     145                       'reference.')
#     146         return False
#
# File d:\Matthieu\tracto\.venv\Lib\site-packages\dipy\io\utils.py:362, in is_header_compatible(reference_1, reference_2)
#     344 def is_header_compatible(reference_1, reference_2):
#     345     """ Will compare the spatial attribute of 2 references
#     346
#     347     Parameters
#    (...)
#     359         Does all the spatial attribute match
#     360     """
# --> 362     affine_1, dimensions_1, voxel_sizes_1, voxel_order_1 = get_reference_info(
#     363         reference_1)
#     364     affine_2, dimensions_2, voxel_sizes_2, voxel_order_2 = get_reference_info(
#     365         reference_2)
#     367     identical_header = True
#
# File d:\Matthieu\tracto\.venv\Lib\site-packages\dipy\io\utils.py:284, in get_reference_info(reference)
#     282     is_nifti = True
#     283 elif ext == '.trk':
# --> 284     header = nib.streamlines.load(reference, lazy_load=True).header
#     285     is_trk = True
#     286 elif ext == '.trx':
#
# File d:\Matthieu\tracto\.venv\Lib\site-packages\nibabel\streamlines\__init__.py:95, in load(fileobj, lazy_load)
#      92 if tractogram_file is None:
#      93     raise ValueError(f"Unknown format for 'fileobj': {fileobj}")
# ---> 95 return tractogram_file.load(fileobj, lazy_load=lazy_load)
#
# File d:\Matthieu\tracto\.venv\Lib\site-packages\nibabel\streamlines\trk.py:318, in TrkFile.load(cls, fileobj, lazy_load)
#     291 @classmethod
#     292 def load(cls, fileobj, lazy_load=False):
#     293     """Loads streamlines from a filename or file-like object.
#     294
#     295     Parameters
#    (...)
#     316     voxel.
#     317     """
# --> 318     hdr = cls._read_header(fileobj)
#     320     # Find scalars and properties name
#     321     data_per_point_slice = {}
#
# File d:\Matthieu\tracto\.venv\Lib\site-packages\nibabel\streamlines\trk.py:568, in TrkFile._read_header(fileobj)
#     565 # Record start position if this is a file-like object
#     566 start_position = fileobj.tell() if hasattr(fileobj, 'tell') else None
# --> 568 with Opener(fileobj) as f:
#     569     # Reading directly from a file into a (mutable) bytearray enables a zero-copy
#     570     # cast to a mutable numpy object with frombuffer
#     571     header_buf = bytearray(header_2_dtype.itemsize)
#     572     f.readinto(header_buf)
#
# File d:\Matthieu\tracto\.venv\Lib\site-packages\nibabel\openers.py:182, in Opener.__init__(self, fileish, *args, **kwargs)
#     179 # Clear keep_open hint if it is not relevant for the file type
#     180 else:
#     181     kwargs.pop('keep_open', None)
# --> 182 self.fobj = opener(fileish, *args, **kwargs)
#     183 self._name = fileish
#     184 self.me_opened = True
#
# FileNotFoundError: [Errno 2] No such file or directory: './Stack_Synthetic_Data_Anti-Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen.trk'

# %% [markdown]
# The following cells convert the tractogram into a [neuroglancer precomputed skeleton format](https://github.com/google/neuroglancer/blob/master/src/datasource/precomputed/skeletons.md).
#
# The first version only supports unsharded format.

# %%
ng_skeleton_path = Path("Stack_Synthetic_Data_Anti-Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel")
ng_skeleton_path.mkdir(exist_ok=True)

# %%
import json
import struct
import numpy as np

def write_info_file(dir_path, affine, sharded = False):
    affine_list_4x3 = affine[:3].flatten().tolist()

    if sharded:
        raise Exception("Not yet implemented")
    else:
        info = {
            "@type": "neuroglancer_skeletons",
            "transform": affine_list_4x3,
            "vertex_attributes": [
                # {
                #     "id": "radius",
                #     "data_type": "float32",
                #     "num_components": 1
                # }
            ],
            #"sharding":
            #"segment_properties": 
        }
    
    with open(dir_path / 'info', 'w') as file:
        json.dump(info, file, indent=4)  # `indent=4` makes the file readable with pretty print

def write_unsharded_skeleton_data(dir_path, streamline_coords):
    for i in range(len(streamline_coords)):
        vertex_positions = np.array(streamline_coords[i], dtype=np.float32)
        num_vertices = len(vertex_positions)
        num_edges = num_vertices - 1
        assert vertex_positions.shape == (num_vertices, 3)
        edges = np.array([(i, i + 1) for i in range(num_vertices - 1)], dtype=np.uint32)
        assert edges[-1][1] == num_vertices - 1
        assert edges.shape == (num_edges, 2)

        with open(dir_path / str(i), 'wb') as file:
            """"""
            file.write(struct.pack('<I', num_vertices))
            file.write(struct.pack('<I', num_edges))
            file.write(vertex_positions.astype('<f4').tobytes())
            file.write(edges.astype('<u4').tobytes())

write_info_file(ng_skeleton_path, affine, sharded=False)
write_unsharded_skeleton_data(ng_skeleton_path, streamline_coords)

# %% [markdown]
# The dataset is now converted. To be able to visualise it locally, you will need:
#
# 1. a local neuroglancer server and
#
# 2. a local HTTP server (with CORS resolver) to the dataset.

# %%
## 1. local neuroglancer server

import neuroglancer
import numpy as np

viewer = neuroglancer.Viewer()
print(viewer)
# Out:
# http://127.0.0.1:60470/v/292cb8269e5697b1f8f1be74334362348b4267c6/

# %%
## 2. local HTTP server (with CORS resolver) to the dataset

import http.server
import socketserver
import os

PORT = 8000
DIRECTORY = "."

class CORSRequestHandler(http.server.SimpleHTTPRequestHandler):
    def end_headers(self):
        self.send_header('Access-Control-Allow-Origin', '*')
        self.send_header('Access-Control-Allow-Methods', 'GET')
        self.send_header('Access-Control-Allow-Headers', 'Content-Type')
        super().end_headers()

    def __init__(self, *args, **kwargs):
        super().__init__(*args, directory=DIRECTORY, **kwargs)

with socketserver.TCPServer(("", PORT), CORSRequestHandler) as httpd:
    print(f"Serving HTTP on port {PORT}...")
    httpd.serve_forever()
# Out:
# Serving HTTP on port 8000...
# 127.0.0.1 - - [08/Aug/2024 10:15:36] code 404, message File not found
# 127.0.0.1 - - [08/Aug/2024 10:15:36] "GET /info HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Aug/2024 10:15:44] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:15:46] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:15:58] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/ HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:16:00] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/info HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:17:02] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:17:05] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngsegprops/ HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:17:06] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngsegprops/info HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:25] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:28] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngsegprops/ HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/2055 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/1519 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/11034 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/4191 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/11980 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/5345 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/8972 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/5965 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/1669 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/6943 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/6388 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/8362 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/12338 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/356 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/7551 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/6546 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/6249 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/4604 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/7441 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/10381 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/12274 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/11327 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/2528 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/3926 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/10995 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/2564 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/11622 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/1910 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/5574 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/7750 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/10244 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/6441 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/1244 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/4496 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/6025 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/6498 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/11001 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/9908 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/1251 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/11114 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/4155 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/6074 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/9044 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:52] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/8098 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/10273 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/12103 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/1654 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/5022 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/5847 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/4584 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/10607 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/6327 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/4495 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/3906 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/9647 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/10548 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/1401 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/7198 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/6725 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/12026 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/1724 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/10055 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/10115 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/10382 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/2187 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/10150 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/5514 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/5041 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/4624 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/4151 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/4648 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/1045 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/12251 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/1545 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/7439 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/8927 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/8219 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/12499 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/455 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/492 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/8659 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/2626 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/11062 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/2153 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/9232 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/2732 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/10280 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/2450 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/2690 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/11896 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/5285 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/6968 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/4833 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/897 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/8912 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/1911 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/1854 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/6023 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/928 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/6793 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/8001 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/6512 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/9165 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/11080 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/4625 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/9132 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/10075 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/4621 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/763 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/5206 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/11222 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/2600 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/12116 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/7232 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/4929 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/6286 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/2665 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/1563 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/6659 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/7840 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/3472 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/10720 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/318 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/2672 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/10969 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/1130 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/11157 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/11349 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/3138 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/9342 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/7395 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/9738 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/3159 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/9585 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/6908 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/12222 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/6155 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:53] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/1533 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/3760 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/3287 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/1449 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/2755 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/1538 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/10460 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/7128 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/1009 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/10388 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/4394 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/976 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/7264 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/11098 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/8235 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/4091 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/7101 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/8540 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/426 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/10277 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/5291 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/2423 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/10066 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/5442 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/3603 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/12206 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/967 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/4760 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/790 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/5318 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/9357 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/11619 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/7394 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/4560 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/8683 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/5627 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/5791 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/12346 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/6587 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/847 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/7924 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/7451 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/4618 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/10092 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/11170 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/11252 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/2142 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/1515 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/1286 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/4318 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/12132 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/371 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/5220 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/9243 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/6634 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/11611 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/5560 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/12350 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/10020 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/12358 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/11418 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/9291 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/1054 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/939 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/1759 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/6329 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/10931 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/813 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/5631 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/6104 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/108 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/4437 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/2151 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/7209 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/4006 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/2560 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/10170 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/5215 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/10959 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/4685 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/5683 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/10939 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/10966 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/4281 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/5594 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/3533 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/6951 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/1146 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/5958 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/11956 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/7683 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/10626 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/12128 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/3335 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/11376 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/8751 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/5121 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/676 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/4930 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/8900 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/10930 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/7210 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/10298 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:54] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/2248 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/11696 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/7573 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/11885 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/9629 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/5448 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/10457 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/6567 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/6005 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/5621 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/7583 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/2791 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/2619 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/6076 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/5876 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/531 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/121 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/7495 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/3092 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/6264 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/1067 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/594 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/6293 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/4822 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/5768 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/3209 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/5519 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/2400 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/7318 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/12198 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/3573 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/11754 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/8829 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/1284 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/10121 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/3072 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/11445 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/12391 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/2035 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/4222 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/1916 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/3979 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/6447 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/4488 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/8588 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/4550 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/5641 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/10622 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/4695 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/7642 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/3728 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/3689 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/11544 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/2873 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/8274 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/1342 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/10741 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/10268 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/1328 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/4754 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/9220 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/8799 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/6937 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/5496 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/6845 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/3593 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/5795 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/8326 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/8115 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/1927 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/3355 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/207 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/6103 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/1362 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/2736 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/11095 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/6505 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/3276 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/4330 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2024 10:18:55] "GET /Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngskel/6577 HTTP/1.1" 200 -
# ...
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /login HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 501, message Unsupported method ('POST')
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "POST /mifs/.;/services/LogService HTTP/1.1" 501 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /CFIDE/administrator/enter.cfm?locale=../../../../../../../lib/password.properties%00en HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /login HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /scripts/tools/newdsn.exe?driver=Microsoft%2BAccess%2BDriver%2B%28*.mdb%29&dsn=Web%20SQL&dbq=c:%5Ctemp%5Cxyz.mdb&newdb=CREATE_DB&attr= HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /CFIDE/adminapi/base.cfc?wsdl HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /crossdomain.xml HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 501, message Unsupported method ('POST')
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "POST /index.htm HTTP/1.1" 501 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /login HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /AdvWorks/equipment/catalog_type.asp?ProductType=|shell(%22c:cmd.exe%22)| HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /Orion/Login.aspx HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 501, message Unsupported method ('POST')
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "POST /clients/MyCRL HTTP/1.1" 501 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 501, message Unsupported method ('POST')
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "POST /openam/oauth2/..;/ccversion/Version HTTP/1.1" 501 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /?Class.classLoader.resources.cacheObjectMaxSize=foo HTTP/1.1" 200 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /login HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /ASPSamp/AdvWorks/equipment/catalog_type.asp?ProductType=|shell(%22c:cmd.exe%22)| HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /cgi-bin/config.exp HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /login HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /login HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /common/index.jsf HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /imc/fault/accessMgrServlet HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /CFIDE/adminiapi/ HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /CFIDE/administrator/ HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 501, message Unsupported method ('POST')
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "POST /webconsole/Controller?mode=8700&operation=1&datagrid=179&json={%22ð\x9f¦\x9e%22:%22test%22} HTTP/1.1" 501 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 501, message Unsupported method ('POST')
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "POST /cgi/login HTTP/1.1" 501 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /conf/ssl/apache/integrity.key HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /struts2-blank/example/HelloWorld.action HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /CFIDE/AIR/ HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 501, message Unsupported method ('POST')
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "POST /data/login HTTP/1.1" 501 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /CFIDE/administrator/enter.cfm HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /CFIDE/wizards/common/ HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "HEAD http://www.google.com:80/ HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /conf/ssl/apache/integrity-smartcenter.key HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /Orion/Login.aspx HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /phpmyadmin/ HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /~bin/true HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /CFIDE/orm/ HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /cgi-bin/awstats.pl?debug=1 HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /moveitisapi/moveitisapi.dll?action=capa HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 501, message Unsupported method ('POST')
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "POST /createou HTTP/1.1" 501 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /login HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /index_sso.php HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /CFIDE/adminapi/customtags/l10n.cfm?attributes.id=test&attributes.file=../../administrator/mail/download.cfm&filename=../../lib/password.properties&attributes.locale=it&attributes.var=it&attributes.jscript=false&attributes.type=text/html&attributes.charset=UTF-8&thisTag.executionmode=end&thisTag.generatedContent=test HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /login HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /cgi-bin/awstats/awstats.pl?debug=1 HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 501, message Unsupported method ('TRACE')
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "TRACE / HTTP/1.1" 501 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /moveitisapi/moveitisapi.dll?action=capa HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /CFIDE/appdeployment/ HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /CFIDE/adminapi/customtags/l10n.cfm?attributes.id=test&attributes.file=../../administrator/mail/download.cfm&filename=../lib/password.properties&attributes.locale=it&attributes.var=it&attributes.jscript=false&attributes.type=text/html&attributes.charset=UTF-8&thisTag.executionmode=end&thisTag.generatedContent=test HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /login HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /?class.module.classLoader.URLs%5B-1%5D=0 HTTP/1.1" 200 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /dana-na/../dana/html5acc/guacamole/../../../../../../etc/passwd?/dana/html5acc/guacamole/ HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /struts2-showcase/employee/save.action HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /cgi-bin/htgrep/file=index.html&hdr=/etc/passwd HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 501, message Unsupported method ('POST')
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "POST /autodiscover HTTP/1.1" 501 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /login HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /CFIDE/wizards/common/utils.cfc?method=verifyldapserver&vserver=localhost&vport=22&vstart=&vusername=&vpassword=&returnformat=json HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /frame?class.module.classLoader.URLs%5B-1%5D=0 HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /tmui/login.jsp/..%3b/tmui/locallb/workspace/fileRead.jsp?fileName=/etc/f5-release HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 501, message Unsupported method ('POST')
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "POST /./RestAPI/LogonCustomization HTTP/1.1" 501 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /frame/config_main.do?class.module.classLoader.URLs%5B-1%5D=0 HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /sys?class.module.classLoader.URLs%5B-1%5D=0 HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /admin?class.module.classLoader.URLs%5B-1%5D=0 HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /page?class.module.classLoader.URLs%5B-1%5D=0 HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /Telerik.Web.UI.WebResource.axd?type=rau HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 501, message Unsupported method ('POST')
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "POST /cgi-bin/test-cgi HTTP/1.1" 501 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /index?class.module.classLoader.URLs%5B-1%5D=0 HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:37] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:37] "GET /home?class.module.classLoader.URLs%5B-1%5D=0 HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:38] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:38] "GET /CFIDE/portlets/ HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:38] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:38] "GET /CFIDE/services/ HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:38] code 501, message Unsupported method ('POST')
# 10.29.10.79 - - [11/Aug/2024 21:22:38] "POST /samples/messagebroker/http HTTP/1.1" 501 -
# 10.29.10.79 - - [11/Aug/2024 21:22:38] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:38] "GET /Orion/Login.aspx HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:38] code 501, message Unsupported method ('POST')
# 10.29.10.79 - - [11/Aug/2024 21:22:38] "POST /samples/messagebroker/httpsecure HTTP/1.1" 501 -
# 10.29.10.79 - - [11/Aug/2024 21:22:38] code 501, message Unsupported method ('POST')
# 10.29.10.79 - - [11/Aug/2024 21:22:38] "POST /lcds/messagebroker/http HTTP/1.1" 501 -
# 10.29.10.79 - - [11/Aug/2024 21:22:38] code 501, message Unsupported method ('POST')
# 10.29.10.79 - - [11/Aug/2024 21:22:38] "POST /lcds/messagebroker/httpsecure HTTP/1.1" 501 -
# 10.29.10.79 - - [11/Aug/2024 21:22:38] code 501, message Unsupported method ('POST')
# 10.29.10.79 - - [11/Aug/2024 21:22:38] "POST /lcds-samples/messagebroker/http HTTP/1.1" 501 -
# 10.29.10.79 - - [11/Aug/2024 21:22:38] code 501, message Unsupported method ('POST')
# 10.29.10.79 - - [11/Aug/2024 21:22:38] "POST /lcds-samples/messagebroker/httpsecure HTTP/1.1" 501 -
# 10.29.10.79 - - [11/Aug/2024 21:22:43] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:43] "GET /rest/v1/AccountService/Accounts HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:43] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:43] "HEAD /index.php HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:43] code 501, message Unsupported method ('POST')
# 10.29.10.79 - - [11/Aug/2024 21:22:43] "POST /cgi-bin/webcgi/login HTTP/1.1" 501 -
# 10.29.10.79 - - [11/Aug/2024 21:22:43] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:43] "GET /mgmt/tm/ltm/pool HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:43] "GET / HTTP/1.1" 200 -
# 10.29.10.79 - - [11/Aug/2024 21:22:43] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:43] "GET /portal/diag/index.jsp HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:43] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:43] "GET /index.html HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:43] code 501, message Unsupported method ('POST')
# 10.29.10.79 - - [11/Aug/2024 21:22:43] "POST _async/AsyncResponseService HTTP/1.1" 501 -
# 10.29.10.79 - - [11/Aug/2024 21:22:43] code 400, message Bad request version ("µàÈ\\x9ce÷~}Ñ\\x1a+\\x00f\\x13\\x02\\x13\\x01À,À+À0À/\\x00\\x9f\\x00£\\x00\\x9e\\x00¢À$À(À#À'\\x00k\\x00j\\x00g\\x00@À.À2À-À1À&À*À%À)À")
# 10.29.10.79 - - [11/Aug/2024 21:22:43] "\x16\x03\x03\x01\x8f\x01\x00\x01\x8b\x03\x03î!7\x8f\x87uèA÷\x9eÕtM\x81Ù¬\x9fº}vÊ\x121\x03ãÞÓC×§\x0d] \x98\x89ã\x94>,4É\x9f$c\x94b\x1aAÈ2iIO\x85µàÈ\x9ce÷~}Ñ\x1a+\x00f\x13\x02\x13\x01À,À+À0À/\x00\x9f\x00£\x00\x9e\x00¢À$À(À#À'\x00k\x00j\x00g\x00@À.À2À-À1À&À*À%À)À" 400 -
# 10.29.10.79 - - [11/Aug/2024 21:22:43] code 400, message Bad request version ('"5ÁAÃ\\x88\\x94ðb\\x02\\x10\\x07G\\x00f\\x13\\x02\\x13\\x01À,À+À0À/\\x00\\x9f\\x00£\\x00\\x9e\\x00¢À$À(À#À\\'\\x00k\\x00j\\x00g\\x00@À.À2À-À1À&À*À%À)À')
# 10.29.10.79 - - [11/Aug/2024 21:22:43] "\x16\x03\x03\x01\x8f\x01\x00\x01\x8b\x03\x03b0\x0d\x02ëZPAÍ±³u§÷y~\x06\x7f\x1a¦âÛDM\x0cá\x96"ä\x96@T vb\x1b\x12\x89??Ã\x93ÍÜá!°$RÕÊ "5ÁAÃ\x88\x94ðb\x02\x10\x07G\x00f\x13\x02\x13\x01À,À+À0À/\x00\x9f\x00£\x00\x9e\x00¢À$À(À#À'\x00k\x00j\x00g\x00@À.À2À-À1À&À*À%À)À" 400 -
# 10.29.10.79 - - [11/Aug/2024 21:22:43] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:43] "GET /index.html HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:43] code 404, message File not found
# 10.29.10.79 - - [11/Aug/2024 21:22:43] "GET /index.html HTTP/1.1" 404 -
# 10.29.10.79 - - [11/Aug/2024 21:22:43] code 501, message Unsupported method ('POST')
# 10.29.10.79 - - [11/Aug/2024 21:22:43] "POST /EemAdminService/EemAdmin HTTP/1.1" 501 -

# %%
import pandas as pd
from nglui.segmentprops import SegmentProperties
from pathlib import Path
import json

df = pd.DataFrame(
    {'segment_id': list(range(0,12520)),
     'fiber_type': ['cortical']*12520}
)

seg_props = SegmentProperties.from_dataframe(
    df,
    id_col='segment_id',
    tag_value_cols='fiber_type'
)

ng_segprops_path = Path("Stack_Synthetic_Data_Parallel_Cylinders_Random_Dia_512X512_filtered50vxlen_ngsegprops")
ng_segprops_path.mkdir(exist_ok=True)

with open(ng_segprops_path / 'info', 'w') as file:
    json.dump(seg_props.to_dict(), file, indent=4)  # `indent=4` makes the file readable with pretty print
